# %% [markdown]
# #Mobile Price Clasification
#
# Bob has started his own mobile company. He wants to give tough fight to big companies like Apple,Samsung etc.
#
# He does not know how to estimate price of mobiles his company creates. In this competitive mobile phone market you cannot simply assume things. To solve this problem he collects sales data of mobile phones of various companies.
#
# Bob wants to find out some relation between features of a mobile phone(eg:- RAM,Internal Memory etc) and its selling price. But he is not so good at Machine Learning. So he needs your help to solve this problem.
#
# In this problem you do not have to predict actual price but a price range indicating how high the price is.
#
# Dataset variable description as follows:
#
# ID: ID
#
# battery_power: Total energy a battery can store in one time measured in mAh
#
# blue: Has bluetooth or not
#
# clock_speed: speed at which microprocessor executes instructions
#
# dual_sim: Has dual sim support or not
#
# fc: Front Camera mega pixels
#
# four_g: Has 4G or not
#
# int_memory: Internal Memory in Gigabytes
#
# m_dep: Mobile Depth in cm
#
# mobile_wt: Weight of mobile phone
#
# n_cores: Number of cores of processor
#
# pc: Primary Camera mega pixels
#
# px_height: Pixel Resolution Height
#
# px_width: Pixel Resolution Width
#
# ram: Random Access Memory in Megabytes
#
# sc_h: Screen Height of mobile in cm
#
# sc_w: Screen Width of mobile in cm
#
# talk_time: longest time that a single battery charge will last when you are
#
# three_g: Has 3G or not
#
# touch_screen: Has touch screen or not
#
# wifi: Has wifi or not

# %% [markdown]
# ##Import library and read file from google drive

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# !pip install -U -q PyDrive
 
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials
 
 
# Authenticate and create the PyDrive client.
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

link = 'https://drive.google.com/file/d/1nIfjLqHfdnkQcGkjK5z6trzgtmVOFAp0/view?usp=sharing'
 
 
# to get the id part of the file
id = link.split("/")[-2]
 
downloaded = drive.CreateFile({'id':id})
downloaded.GetContentFile('train.csv') 
 
df = pd.read_csv('train.csv')
print(df)
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0               842     0          2.2         0   1       0           7
# 1              1021     1          0.5         1   0       1          53
# 2               563     1          0.5         1   2       1          41
# 3               615     1          2.5         0   0       0          10
# 4              1821     1          1.2         0  13       1          44
# ...             ...   ...          ...       ...  ..     ...         ...
# 1995            794     1          0.5         1   0       1           2
# 1996           1965     1          2.6         1   0       0          39
# 1997           1911     0          0.9         1   1       1          36
# 1998           1512     0          0.9         0   4       1          46
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# ...

# %% [markdown]
# ##Making EDA

# %%
df.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2  ...         20       756  2549     9     7         19
# 1        136        3  ...        905      1988  2631    17     3          7
# 2        145        5  ...       1263      1716  2603    11     2          9
# 3        131        6  ...       1216      1786  2769    16     8         11
# 4        141        2  ...       1208      1212  1411     8     2         15
#
# ...

# %%
# See the shape of the dataset
df.shape
# Out:
# (2000, 21)

# %%
# checking columns in df
df.columns
# Out:
# Index(['battery_power', 'blue', 'clock_speed', 'dual_sim', 'fc', 'four_g',
#        'int_memory', 'm_dep', 'mobile_wt', 'n_cores', 'pc', 'px_height',
#        'px_width', 'ram', 'sc_h', 'sc_w', 'talk_time', 'three_g',
#        'touch_screen', 'wifi', 'price_range'],
#       dtype='object')

# %%
# Check the information from df
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   battery_power  2000 non-null   int64
#  1   blue           2000 non-null   int64
#  2   clock_speed    2000 non-null   float64
#  3   dual_sim       2000 non-null   int64
#  4   fc             2000 non-null   int64
#  5   four_g         2000 non-null   int64
#  6   int_memory     2000 non-null   int64
#  7   m_dep          2000 non-null   float64
#  8   mobile_wt      2000 non-null   int64
#  9   n_cores        2000 non-null   int64
#  10  pc             2000 non-null   int64
#  11  px_height      2000 non-null   int64
#  12  px_width       2000 non-null   int64
#  13  ram            2000 non-null   int64
#  14  sc_h           2000 non-null   int64
#  15  sc_w           2000 non-null   int64
#  16  talk_time      2000 non-null   int64
#  17  three_g        2000 non-null   int64
# ...

# %%
# See the description
df.describe().T
# Out:
#                 count        mean          std    min      25%     50%  \
# battery_power  2000.0  1238.51850   439.418206  501.0   851.75  1226.0
# blue           2000.0     0.49500     0.500100    0.0     0.00     0.0
# clock_speed    2000.0     1.52225     0.816004    0.5     0.70     1.5
# dual_sim       2000.0     0.50950     0.500035    0.0     0.00     1.0
# fc             2000.0     4.30950     4.341444    0.0     1.00     3.0
# four_g         2000.0     0.52150     0.499662    0.0     0.00     1.0
# int_memory     2000.0    32.04650    18.145715    2.0    16.00    32.0
# m_dep          2000.0     0.50175     0.288416    0.1     0.20     0.5
# mobile_wt      2000.0   140.24900    35.399655   80.0   109.00   141.0
# n_cores        2000.0     4.52050     2.287837    1.0     3.00     4.0
# pc             2000.0     9.91650     6.064315    0.0     5.00    10.0
# px_height      2000.0   645.10800   443.780811    0.0   282.75   564.0
# ...

# %%
df['price_range'].describe()
# Out:
# count    2000.000000
# mean        1.500000
# std         1.118314
# min         0.000000
# 25%         0.750000
# 50%         1.500000
# 75%         2.250000
# max         3.000000
# Name: price_range, dtype: float64

# %%
# Find the number of unique Values
df.nunique()
# Out:
# battery_power    1094
# blue                2
# clock_speed        26
# dual_sim            2
# fc                 20
# four_g              2
# int_memory         63
# m_dep              10
# mobile_wt         121
# n_cores             8
# pc                 21
# px_height        1137
# px_width         1109
# ram              1562
# sc_h               15
# sc_w               19
# talk_time          19
# three_g             2
# touch_screen        2
# wifi                2
# price_range         4
# dtype: int64

# %%
df['price_range'].unique()
# Out:
# array([1, 2, 3, 0])

# %%
# Check missing value
df.isnull().sum()
# Out:
# battery_power    0
# blue             0
# clock_speed      0
# dual_sim         0
# fc               0
# four_g           0
# int_memory       0
# m_dep            0
# mobile_wt        0
# n_cores          0
# pc               0
# px_height        0
# px_width         0
# ram              0
# sc_h             0
# sc_w             0
# talk_time        0
# three_g          0
# touch_screen     0
# wifi             0
# price_range      0
# dtype: int64

# %%
categorical_features=list()
numeric_features=list()
for column_name in df.columns:
    unique_values = len(df[column_name].unique())
    if unique_values<30:
      categorical_features.append(column_name)
    else:
      numeric_features.append(column_name)

# %%
categorical_features
# Out:
# ['blue',
#  'clock_speed',
#  'dual_sim',
#  'fc',
#  'four_g',
#  'm_dep',
#  'n_cores',
#  'pc',
#  'sc_h',
#  'sc_w',
#  'talk_time',
#  'three_g',
#  'touch_screen',
#  'wifi',
#  'price_range']

# %%
numeric_features
# Out:
# ['battery_power', 'int_memory', 'mobile_wt', 'px_height', 'px_width', 'ram']

# %%
pd.crosstab(df['blue'], df['price_range'])
# Out:
# price_range    0    1    2    3
# blue
# 0            257  255  257  241
# 1            243  245  243  259

# %%
pd.crosstab(df['wifi'], df['price_range'])
# Out:
# price_range    0    1    2    3
# wifi
# 0            252  248  248  238
# 1            248  252  252  262

# %%
pd.crosstab(df['dual_sim'], df['price_range'])
# Out:
# price_range    0    1    2    3
# dual_sim
# 0            250  245  251  235
# 1            250  255  249  265

# %%
pd.crosstab(df['three_g'], df['price_range'])
# Out:
# price_range    0    1    2    3
# three_g
# 0            127  122  113  115
# 1            373  378  387  385

# %%
pd.crosstab(df['four_g'], df['price_range'])
# Out:
# price_range    0    1    2    3
# four_g
# 0            241  238  253  225
# 1            259  262  247  275

# %% [markdown]
# ##Visualization

# %%
# Bluetooth
sns.countplot(x = df['blue'], hue='price_range', data = df, palette=["#ffeda0", "#5ab4ac", "#d8b365", "#7fcdbb"])

# %%
#Wifi
sns.countplot(x = df['wifi'], hue='price_range', data = df, palette=["#ffeda0", "#5ab4ac", "#d8b365", "#7fcdbb"])

# %%
#Dual sim
sns.countplot(x = df['dual_sim'], hue='price_range', data = df, palette=["#ffeda0", "#5ab4ac", "#d8b365", "#7fcdbb"])

# %%
plt.figure(figsize=[14,5])
sns.set_palette("deep")
plt.subplot(1,2,1)
sns.countplot(x = df['price_range'], data = df, palette=["#ffeda0", "#5ab4ac", "#d8b365", "#7fcdbb"])
plt.subplot(1,2,2)
sns.set_palette("bright")
plt.pie(
    x=df["price_range"].value_counts().values,
    labels=df["price_range"].value_counts().keys(),
    startangle=45,
    autopct="%.2f%%",
    colors=["#ffeda0", "#5ab4ac", "#d8b365", "#7fcdbb"]
)

plt.show()

# %%
plt.figure(figsize=[14,10])
sns.set_palette("deep")
plt.subplot(2,2,1)
sns.countplot(x = df['fc'], data = df, palette=["#7fcdbb"])
plt.subplot(2,2,2)
sns.boxplot(x='price_range', y='fc', data=df, palette=["#ffeda0", "#5ab4ac", "#d8b365", "#7fcdbb"])
plt.subplot(2,2,3)
sns.countplot(x = df['pc'], data = df, palette=["#5ab4ac"])
plt.subplot(2,2,4)
sns.boxplot(x='price_range', y='pc', data=df, palette=["#ffeda0", "#5ab4ac", "#d8b365", "#7fcdbb"])

# %%
#px_height and px_width
sns.scatterplot(data = df, x='px_height', y='px_width')

# %%
#px with pc and price_range
plt.figure(figsize=[14,10])
sns.set_palette("deep")
plt.subplot(2,2,1)
sns.scatterplot(data = df, x='pc', y='px_height')
plt.subplot(2,2,2)
sns.boxplot(x='price_range', y='px_height', data=df, palette=["#ffeda0", "#5ab4ac", "#d8b365", "#7fcdbb"])
plt.subplot(2,2,3)
sns.scatterplot(data = df, x='pc', y='px_width')
plt.subplot(2,2,4)
sns.boxplot(x='price_range', y='px_width', data=df, palette=["#ffeda0", "#5ab4ac", "#d8b365", "#7fcdbb"])

# %%
plt.figure(figsize=[15,10])
sns.set_palette("deep")
plt.subplot(2,2,1)
sns.countplot(x = df['three_g'], data = df, palette=["#c51b8a"])
plt.subplot(2,2,2)
plt.pie(
    x=df["three_g"].value_counts().values,
    labels=df["three_g"].value_counts().keys(),
    startangle=45,
    autopct="%.2f%%",
    colors=["#f768a1", "#ae017e"]
)

plt.subplot(2,2,3)
sns.countplot(x = df['four_g'], data = df, palette=["#c51b8a"])
plt.subplot(2,2,4)
plt.pie(
    x=df["four_g"].value_counts().values,
    labels=df["four_g"].value_counts().keys(),
    startangle=45,
    autopct="%.2f%%",
    colors=["#f768a1", "#ae017e"]
)
# Out:
# ([<matplotlib.patches.Wedge at 0x7f0783345290>,
# ...
#  [Text(-0.8285409774513126, 0.7235467149286381, '1'),
#   Text(0.8285409774513125, -0.7235467149286382, '0')],
#  [Text(-0.45193144224617043, 0.3946618445065298, '52.15%'),
#   Text(0.4519314422461704, -0.39466184450652986, '47.85%')])

# %%
#Scatter for memory and ram and measure by price_range
plt.figure(figsize=[16,6])
sns.scatterplot(x='int_memory',y='ram',data=df,hue='price_range', palette=["#fbb4b9","#f768a1", "#ae017e", "#7a0177"])

# %%
#Lineplot for n_cores and int_memory in clock_speed
plt.figure(figsize=[10,8])
plt.subplot(2,1,1)
sns.lineplot(x=df.n_cores,y=df.clock_speed,data=df,err_style='bars')
plt.subplot(2,1,2)
sns.lineplot(x=df.int_memory,y=df.clock_speed,data=df,err_style='band')

# %%
plt.figure(figsize=(15,10))
sns.heatmap(
    df.corr(), annot=True, linewidths=.2, fmt= '.1f')
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.title("Correlation Map", fontsize=20)
plt.show()

# %% [markdown]
# ####Jika diliat dari heatmap, yang memiliki korelasi dengan price_range yaitu ram, px_width, px_height, dan battery_power. Namun untuk korelasi yang kuat nya hanya pada kolom ram, untuk battery_power dan px_height dan px_width hanya memiliki korelasi yang lemah

# %% [markdown]
# ##Modelling in Machine Learning

# %% [markdown]
# ###Do splitting test

# %%
from sklearn.model_selection import train_test_split # for split the data into data train and test

# %%
x = df.loc[:, df.columns != 'price_range']
y = df['price_range']

# %%
#print x or y
x.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  pc  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2   2         20       756  2549     9     7         19
# 1        136        3   6        905      1988  2631    17     3          7
# 2        145        5   6       1263      1716  2603    11     2          9
# 3        131        6   9       1216      1786  2769    16     8         11
# 4        141        2  14       1208      1212  1411     8     2         15
#
#    three_g  touch_screen  wifi
# ...

# %%
x.shape
# Out:
# (2000, 20)

# %%
y.value_counts().sort_values()
# Out:
# 1    500
# 2    500
# 3    500
# 0    500
# Name: price_range, dtype: int64

# %%
# Declare variable for splitting x and y into train and test
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=1)

# %%
#Print to make sure the train or test data in x or y
X_test.head()
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 674            1034     0          2.6         1   2       1          45
# 1699           1002     1          1.8         0   1       0          45
# 1282            609     1          0.5         0   4       1          10
# 1315           1510     0          0.6         1   1       0          32
# 1210            805     1          1.7         1   0       1          58
#
#       m_dep  mobile_wt  n_cores  pc  px_height  px_width   ram  sc_h  sc_w  \
# 674     0.3        190        3   4        182      1293   969    15     1
# 1699    0.7        180        7   7        948      1007  1234    19    13
# 1282    0.1         81        6   6        113      1524  1905    16     3
# 1315    0.7        135        3   8        963      1520   854     8     2
# 1210    0.9        168        3  10         81      1544  3397     7     6
#
#       talk_time  three_g  touch_screen  wifi
# ...

# %%
y_test.head()
# Out:
# 674     0
# 1699    0
# 1282    1
# 1315    1
# 1210    2
# Name: price_range, dtype: int64

# %% [markdown]
# ###Logistic Regression model

# %%
from sklearn.linear_model import LogisticRegression
# using logistic regression by default
lr = LogisticRegression()
lr.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# LogisticRegression()

# %%
lr.score(X_test, y_test)
# Out:
# 0.6283333333333333

# %% [markdown]
# ###Decision Tree model

# %%
from sklearn.tree import DecisionTreeClassifier
dtree = DecisionTreeClassifier()
dtree.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
dtree.score(X_test, y_test)
# Out:
# 0.86

# %% [markdown]
# ###Random Forest model

# %%
from sklearn.ensemble import RandomForestClassifier
rfc = RandomForestClassifier(n_estimators=200)
rfc.fit(X_train, y_train)
# Out:
# RandomForestClassifier(n_estimators=200)

# %%
rfc.score(X_test, y_test)
# Out:
# 0.8733333333333333

# %% [markdown]
# ###KNeighbors

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier()
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
knn.score(X_test, y_test)
# Out:
# 0.92

# %% [markdown]
# ##Hyperparameter Tuning

# %%
rf = RandomForestClassifier(random_state=42, n_jobs=-1)

# %%
params = {
    'max_depth': [2,3,5,10,20],
    'min_samples_leaf': [5,10,20,50,100,200],
    'n_estimators': [10,25,30,50,100,200]
}

# %%
from sklearn.model_selection import GridSearchCV

grid_search = GridSearchCV(estimator=rf,
                           param_grid=params,
                           cv = 4,
                           n_jobs = -1, verbose = 1, scoring="accuracy")

grid_search.fit(X_train, y_train)
# Out:
# Fitting 4 folds for each of 180 candidates, totalling 720 fits
# GridSearchCV(cv=4, estimator=RandomForestClassifier(n_jobs=-1, random_state=42),
#              n_jobs=-1,
#              param_grid={'max_depth': [2, 3, 5, 10, 20],
#                          'min_samples_leaf': [5, 10, 20, 50, 100, 200],
#                          'n_estimators': [10, 25, 30, 50, 100, 200]},
#              scoring='accuracy', verbose=1)

# %%
#Mencari tahu skor terbaik dari grid search
grid_search.best_score_
# Out:
# 0.8592857142857143

# %%
# Mencari tahu parameter yang terbaik
rf_best = grid_search.best_estimator_
rf_best.fit(X_train, y_train)
# Out:
# RandomForestClassifier(max_depth=20, min_samples_leaf=5, n_estimators=50,
#                        n_jobs=-1, random_state=42)

# %% [markdown]
# ##Evaluation

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score

# %%
y_lr = lr.predict(X_test)
y_dtree = dtree.predict(X_test)
y_rfc = rfc.predict(X_test)
y_grid_rfc = grid_search.predict(X_test)
y_knn = knn.predict(X_test)

# %%
#accuracy_score
print('Akurasi untuk Logistic Regression: ', round(accuracy_score(y_test, y_lr), 2))
print('Akurasi untuk Decision Tree', round(accuracy_score(y_test, y_dtree), 2))
print('Akurasi untuk Random Forest', round(accuracy_score(y_test, y_rfc), 2))
print('Akurasi untuk Random Forest (Tuning)', round(accuracy_score(y_test, y_grid_rfc), 2))
print('Akurasi untuk KNeighbors ', round(accuracy_score(y_test, y_knn), 2))
# Out:
# Akurasi untuk Logistic Regression:  0.63
# Akurasi untuk Decision Tree 0.86
# Akurasi untuk Random Forest 0.87
# Akurasi untuk Random Forest (Tuning) 0.84
# Akurasi untuk KNeighbors  0.92

# %%
#Precision score variable
round_precision_score_lr = round(precision_score(y_test, y_lr, average='macro'), 2)
round_precision_score_dtree = round(precision_score(y_test, y_dtree, average='macro'), 2)
round_precision_score_rfc = round(precision_score(y_test, y_rfc, average='macro'), 2)
round_precision_score_rfc_tuning = round(precision_score(y_test, y_grid_rfc, average='macro'), 2)
round_precision_score_knn = round(precision_score(y_test, y_knn, average='macro'), 2)

# %%
#print precision score
print('Precision score untuk Logistic Regression: ', round_precision_score_lr)
print('Precision score untuk Decision Tree: ', round_precision_score_dtree)
print('Precision score untuk Random Forest: ', round_precision_score_rfc)
print('Precision score untuk Random Forest(Tuning): ', round_precision_score_rfc_tuning)
print('Precision score untuk KNeighbors: ', round_precision_score_knn)
# Out:
# Precision score untuk Logistic Regression:  0.63
# Precision score untuk Decision Tree:  0.87
# Precision score untuk Random Forest:  0.87
# Precision score untuk Random Forest(Tuning):  0.85
# Precision score untuk KNeighbors:  0.92

# %%
# Recall score variable
round_recall_score_lr = round(recall_score(y_test, y_lr, average='macro'), 2)
round_recall_score_dtree = round(recall_score(y_test, y_dtree, average='macro'), 2)
round_recall_score_rfc = round(recall_score(y_test, y_rfc, average='macro'), 2)
round_recall_score_rfc_tuning = round(recall_score(y_test, y_grid_rfc, average='macro'), 2)
round_recall_score_knn = round(recall_score(y_test, y_knn, average='macro'), 2)

# %%
#print recall_score
print('Recall score untuk Logistic Regression: ', round_recall_score_lr)
print('Recall score untuk Decision Tree: ', round_recall_score_dtree)
print('Recall score untuk Random Forest: ', round_recall_score_rfc)
print('Recall score untuk Random Forest (Tuning): ', round_recall_score_rfc_tuning)
print('Recall score untuk KNeighbors: ', round_recall_score_knn)
# Out:
# Recall score untuk Logistic Regression:  0.64
# Recall score untuk Decision Tree:  0.86
# Recall score untuk Random Forest:  0.88
# Recall score untuk Random Forest (Tuning):  0.85
# Recall score untuk KNeighbors:  0.92

# %%
from sklearn.metrics import classification_report

print('Report untuk Logistic Regression: \n', classification_report(y_test, y_lr))
print('Report untuk Decision Tree: \n', classification_report(y_test, y_dtree))
print('Report untuk Random Forest: \n', classification_report(y_test, y_rfc))
print('Report untuk Random Forest (Tuning): \n', classification_report(y_test, y_grid_rfc))
print('Report untuk KNeighbors: \n', classification_report(y_test, y_knn))
# Out:
# Report untuk Logistic Regression:
#                precision    recall  f1-score   support
#
#            0       0.78      0.80      0.79       135
#            1       0.53      0.58      0.55       149
#            2       0.53      0.40      0.45       168
#            3       0.67      0.78      0.72       148
#
#     accuracy                           0.63       600
#    macro avg       0.63      0.64      0.63       600
# weighted avg       0.62      0.63      0.62       600
#
# Report untuk Decision Tree:
#                precision    recall  f1-score   support
#
#            0       0.93      0.86      0.89       135
#            1       0.76      0.86      0.81       149
#            2       0.87      0.78      0.82       168
#            3       0.90      0.95      0.92       148
#
#     accuracy                           0.86       600
#    macro avg       0.87      0.86      0.86       600
# weighted avg       0.86      0.86      0.86       600
#
# ...
